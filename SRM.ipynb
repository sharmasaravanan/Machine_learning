# %% [markdown]
# ### Reference

# %% [markdown]
# 1. Cheatsheets
#
#     https://drive.google.com/open?id=1aWmEBeUbpshAzgf5wNiiRqO2S5x6R7n2
#
#
# 2. Notebooks
#
#     https://github.com/sharmasaravanan/Machine_learning/blob/master/SRM.ipynb
#
#
# 3. AI-ML Projects repos
#
#     https://github.com/sharmasaravanan?tab=repositories

# %% [markdown]
# ### Contact

# %% [markdown]
# 1. LinkedIn
#
#     https://linkedin.com/in/sharmasaravanan/
#
# 2. Mobile:
#
#     7418490015

# %%
a = 6
b =9 
print(a+b)
# Out:
# 15

# %%
a = 6 #int
b = 3.14 #float
c = "apple"#string
d = True#bool

# %%
print(a)
# Out:
# 6

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
print("Hello world")
# Out:
# Hello world

# %%
# hello 6
# hello apple

# %%
print('hello',a)
print('hello',c)
# Out:
# hello 6
# hello apple

# %%
print('hello '+c)
print('hello '+str(a))
# Out:
# hello apple
# hello 6

# %%
print("hello %d" %a)
print("hello %s" %c)
# Out:
# hello 6
# hello apple

# %%
# I bought 2kgs of mango and 1kg of apple in the market for 150.25Rs

# %%
w1 = 2
w2 = 1
f1 = 'mango'
f2 = 'apple'
p = 150.25

# %%
n = 3
ans = int(str(n)+str(n)+str(n))+int(str(n)+str(n))+n
print(ans)
# Out:
# 369

# %%
n = '5'
int(n+n+n)+int(n+n)+int(n)
# Out:
# 615

# %%
num = int(input("Enter the numerical value : "))
if num % 2 == 0:
    print('even')
else:
    print('Odd')
# Out:
# Enter the numerical value : 6
# even

# %%
i = 1
while i <= 5:
    num = int(input("Enter the numerical value : "))
    if num % 4 == 0:
        print('Divisible by 4 and even')
    elif num % 2 == 0:
        print('even')
    else:
        print('Odd')
    i += 1
# Out:
# Enter the numerical value : 63
# Odd
# Enter the numerical value : 20
# Divisible by 4 and even
# Enter the numerical value : 10
# even
# Enter the numerical value : 5
# Odd
# Enter the numerical value : 14
# even

# %%
opt = 'y'
while opt == 'y':
    num = int(input("Enter the numerical value : "))
    if num % 4 == 0:
        print('Divisible by 4 and even')
    elif num % 2 == 0:
        print('even')
    else:
        print('Odd')
    
    opt = input("Do you want to continue ? y/n : ")
# Out:
# Enter the numerical value : 85
# Odd
# Do you want to continue ? y/n : y
# Enter the numerical value : 63
# Odd
# Do you want to continue ? y/n : lj

# %%
list
tuple
dictionary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b55e7e6df741> in <module>()
#       1 list
#       2 tuple
# ----> 3 dictionary
#
# NameError: name 'dictionary' is not defined

# %%
l = [1,2,3,'a','b','c','apple','ball']
t = (1,2,3,'a','b','c','apple','ball')

# %%
l.append('cat')

# %%
l
# Out:
# [1, 2, 3, 'a', 'b', 'c', 'apple', 'ball', 'cat']

# %%
l.extend([56,'mango'])

# %%
l
# Out:
# [1, 2, 3, 'a', 'b', 'c', 'apple', 'ball', 'cat', 56, 'mango']

# %%
l.index('c')
# Out:
# 5

# %%
l[5]
# Out:
# 'c'

# %%
del l[5]

# %%
l
# Out:
# [1, 2, 3, 'a', 'b', 'apple', 'ball', 'cat', 56, 'mango']

# %%
l.insert(4,"papaya")

# %%
l
# Out:
# [1, 2, 3, 'a', 'papaya', 'b', 'apple', 'ball', 'cat', 56, 'mango']

# %%
l.reverse()

# %%
l
# Out:
# ['mango', 56, 'cat', 'ball', 'apple', 'b', 'papaya', 'a', 3, 2, 1]

# %%
l[::-1]
# Out:
# [1, 2, 3, 'a', 'papaya', 'b', 'apple', 'ball', 'cat', 56, 'mango']

# %%
l
# Out:
# ['mango', 56, 'cat', 'ball', 'apple', 'b', 'papaya', 'a', 3, 2, 1]

# %%
t[5]
# Out:
# 'c'

# %%
del t[5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-716000893082> in <module>()
# ----> 1 del t[5]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
l[6]
# Out:
# 'papaya'

# %%
l[6] = 'pine apple'

# %%
l[6]
# Out:
# 'pine apple'

# %%
t[6]
# Out:
# 'apple'

# %%
t[6] = 'orange'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-5e5f265de831> in <module>()
# ----> 1 t[6] = 'orange'
#
# TypeError: 'tuple' object does not support item assignment

# %%
l
# Out:
# ['mango', 56, 'cat', 'ball', 'apple', 'b', 'pine apple', 'a', 3, 2, 1]

# %%
d = {'a':'apple','b':'ball','c':'cat',2:'papaya','d':45,4:12}

# %%
d
# Out:
# {'a': 'apple', 'b': 'ball', 'c': 'cat', 2: 'papaya', 'd': 45, 4: 12}

# %%
d['c']
# Out:
# 'cat'

# %%
len(l)
# Out:
# 11

# %%
for i in t:
    print(i)
# Out:
# 1
# 2
# 3
# a
# b
# c
# apple
# ball

# %%
for k in d.keys():
    print(k)
# Out:
# a
# b
# c
# 2
# d
# 4

# %%
for v in d.values():
    print(v)
# Out:
# apple
# ball
# cat
# papaya
# 45
# 12

# %%
for k,v in d.items():
    print(k,v)
# Out:
# a apple
# b ball
# c cat
# 2 papaya
# d 45
# 4 12

# %%
pip install pandas

# %%
import pandas as pd

# %%
http://tiny.cc/g09d9y

# %%
excelData = pd.read_excel("./Course Syllabus.xlsx")

# %%
excelData
# Out:
#                      Syllabus    Duration
# 0     Introduction to Python      40 mins
# 1        Environment creation     20 mins
# 2    variables and expression     45 mins
# 3            conditional code     90 mins
# 4                   fucntions    120 mins
# 5         loops and iteration     90 mins
# 6                        List     45 mins
# 7                      Tuples     45 mins
# 8             Data Dictionary     45 mins
# 9               File handling    150 mins
# 10          importing library     40 mins
# 11           random libraries     90 mins
# 12        Sorting, Formatting     45 mins
# 13                 Statistics     45 mins
# 14   basics of flask & django     90 mins
# 15  arrays and graph plotting     90 mins
# 16            Sample Projects  120 mins\n
# 17                Total Hours    20 hours

# %%
sheetData = pd.read_excel("./Course Syllabus.xlsx",sheet_name="Machine Learning")

# %%
sheetData
# Out:
#                                         Syllabus  Duration
# 0             1.Introduction to Machine learning   60 mins
# 1            1.a  Introduction to Data Operation  150 mins
# 2                               Basic Operations       NaN
# 3                             Moving Data Around       NaN
# 4                              Computing on Data       NaN
# 5                                  Plotting Data       NaN
# 6   Control Statements: for, while, if statement       NaN
# 7                                  Vectorization       NaN
# 8           2.Types of ML algorithm- an overview   60 mins
# 9                           Supervisied learning       NaN
# 10                        Unsupervisied Learning       NaN
# 11                        Reinforcement Learning       NaN
# 12                             3.Linear Algebra   180 mins
# 13                          Matrices and Vectors       NaN
# 14            Addition and Scalar Multiplication       NaN
# 15                  Matrix Vector Multiplication       NaN
# 16                  Matrix Matrix Multiplication       NaN
# 17              Matrix Multiplication Properties       NaN
# 18                         Inverse and Transpose       NaN
# 19                 Practice Quiz: Linear Algebra       NaN
# 20                           4.Linear Regression  240 mins
# 21                          Model Representation       NaN
# 22                                 Cost Function       NaN
# 23                              Gradient Descent       NaN
# 24        Gradient Descent For Linear Regression       NaN
# 25            Features and Polynomial Regression       NaN
# 26                               Normal Equation       NaN
# 27              Normal Equation Noninvertibility       NaN
# 28                         5.Logistic Regression  150 mins
# 29                                Classification       NaN
# ..                                           ...       ...
# 34         Multiclass Classification: One-vs-all       NaN
# 35                              5.Regularization   60 mins
# 36                    The Problem of Overfitting       NaN
# 37                 Regularized Linear Regression       NaN
# 38               Regularized Logistic Regression       NaN
# 39              6.Machine Learning System Design   90 mins
# 40                  Prioritizing What to Work On       NaN
# 41                         Inverse and Transpose       NaN
# 42              Error Metrics for Skewed Classes       NaN
# 43              Trading Off Precision and Recall       NaN
# 44                     Data For Machine Learning       NaN
# 45                         7.Supervised Learning  180 mins
# 46                                           SVM       NaN
# 47                             Nearest Neighbour       NaN
# 48                                       Kernels       NaN
# 49                                      few more       NaN
# 50                       8.Unsupervised Learning  180 mins
# 51                             K-Means Algorithm       NaN
# 52                        Optimization Objective       NaN
# 53                         Random Initialization       NaN
# 54               Choosing the Number of Clusters       NaN
# 55                9.Large Scale Machine Learning  120 mins
# 56                  Learning with large datasets       NaN
# 57                   Stochastic Gradient Descent       NaN
# 58                   Mini-Batch Gradient Descent       NaN
# 59       Stochastic Gradient Descent Convergence       NaN
# 60               Map Reduce and Data Parallelism       NaN
# 61                                   10.Practise  180 mins
# 62                               11.Tools for ML  150 mins
# 63                                         TOTAL  30 hours
#
# [64 rows x 2 columns]

# %%
csvData = pd.read_csv("./train.csv")

# %%
csvData.head(3)
# Out:
#             class  petal_length  petal_width  sepal_length  sepal_width
# 0  Iris-virginica           5.5          1.8           6.4          3.1
# 1  Iris-virginica           5.9          2.3           6.8          3.2
# 2  Iris-virginica           5.4          2.3           6.2          3.4

# %%
csvData.describe()
# Out:
#        petal_length  petal_width  sepal_length  sepal_width
# count    105.000000   105.000000    105.000000   105.000000
# mean       3.748571     1.196190      5.830476     3.057143
# std        1.753519     0.765723      0.800015     0.449969
# min        1.000000     0.100000      4.400000     2.000000
# 25%        1.500000     0.300000      5.100000     2.800000
# 50%        4.400000     1.300000      5.700000     3.000000
# 75%        5.100000     1.800000      6.400000     3.400000
# max        6.900000     2.500000      7.700000     4.400000

# %%
csvData.shape
# Out:
# (105, 5)

# %%
x = csvData.loc[:,'petal_length':'sepal_width']

# %%
x.head()
# Out:
#    petal_length  petal_width  sepal_length  sepal_width
# 0           5.5          1.8           6.4          3.1
# 1           5.9          2.3           6.8          3.2
# 2           5.4          2.3           6.2          3.4
# 3           4.8          1.8           6.0          3.0
# 4           5.1          2.3           6.9          3.1

# %%
csvData.drop(columns="class")
# Out:
#      petal_length  petal_width  sepal_length  sepal_width
# 0             5.5          1.8           6.4          3.1
# 1             5.9          2.3           6.8          3.2
# 2             5.4          2.3           6.2          3.4
# 3             4.8          1.8           6.0          3.0
# 4             5.1          2.3           6.9          3.1
# 5             5.6          2.4           6.3          3.4
# 6             5.2          2.3           6.7          3.0
# 7             6.7          2.0           7.7          2.8
# 8             5.8          2.2           6.5          3.0
# 9             5.3          1.9           6.4          2.7
# 10            5.0          2.0           5.7          2.5
# 11            5.1          1.9           5.8          2.7
# 12            5.6          1.8           6.3          2.9
# 13            5.0          1.9           6.3          2.5
# 14            5.8          1.8           6.7          2.5
# 15            5.7          2.1           6.7          3.3
# 16            5.5          1.8           6.5          3.0
# 17            5.6          1.4           6.1          2.6
# 18            5.0          1.5           6.0          2.2
# 19            5.2          2.0           6.5          3.0
# 20            6.1          1.9           7.4          2.8
# 21            6.1          2.3           7.7          3.0
# 22            6.1          2.5           7.2          3.6
# 23            5.9          2.1           7.1          3.0
# 24            6.0          2.5           6.3          3.3
# 25            5.1          1.5           6.3          2.8
# 26            5.1          1.9           5.8          2.7
# 27            6.0          1.8           7.2          3.2
# 28            5.7          2.5           6.7          3.3
# 29            6.9          2.3           7.7          2.6
# ..            ...          ...           ...          ...
# 75            1.5          0.2           5.4          3.7
# 76            1.5          0.2           5.1          3.4
# 77            1.9          0.2           4.8          3.4
# 78            1.5          0.4           5.1          3.7
# 79            1.5          0.1           4.9          3.1
# 80            1.3          0.2           4.4          3.2
# 81            1.3          0.2           5.5          3.5
# 82            1.4          0.3           5.1          3.5
# 83            1.4          0.2           5.0          3.3
# 84            1.6          0.2           4.8          3.4
# 85            1.5          0.2           4.6          3.1
# 86            1.4          0.3           4.8          3.0
# 87            1.6          0.6           5.0          3.5
# 88            1.5          0.2           5.2          3.5
# 89            1.5          0.1           4.9          3.1
# 90            1.4          0.2           5.5          4.2
# 91            1.5          0.4           5.4          3.4
# 92            1.5          0.1           5.2          4.1
# 93            1.0          0.2           4.6          3.6
# 94            1.6          0.2           5.1          3.8
# 95            1.4          0.2           4.6          3.2
# 96            1.4          0.2           4.4          2.9
# 97            1.5          0.3           5.1          3.8
# 98            1.4          0.2           5.0          3.6
# 99            1.3          0.2           4.7          3.2
# 100           1.5          0.2           5.0          3.4
# 101           1.7          0.3           5.7          3.8
# 102           1.3          0.4           5.4          3.9
# 103           1.9          0.4           5.1          3.8
# 104           1.6          0.2           5.0          3.0
#
# [105 rows x 4 columns]

# %%
y = csvData['class']

# %%
y
# Out:
# 0      Iris-virginica
# 1      Iris-virginica
# 2      Iris-virginica
# 3      Iris-virginica
# 4      Iris-virginica
# 5      Iris-virginica
# 6      Iris-virginica
# 7      Iris-virginica
# 8      Iris-virginica
# 9      Iris-virginica
# 10     Iris-virginica
# 11     Iris-virginica
# 12     Iris-virginica
# 13     Iris-virginica
# 14     Iris-virginica
# 15     Iris-virginica
# 16     Iris-virginica
# 17     Iris-virginica
# 18     Iris-virginica
# 19     Iris-virginica
# 20     Iris-virginica
# 21     Iris-virginica
# 22     Iris-virginica
# 23     Iris-virginica
# 24     Iris-virginica
# 25     Iris-virginica
# 26     Iris-virginica
# 27     Iris-virginica
# 28     Iris-virginica
# 29     Iris-virginica
#             ...
# 75        Iris-setosa
# 76        Iris-setosa
# 77        Iris-setosa
# 78        Iris-setosa
# 79        Iris-setosa
# 80        Iris-setosa
# 81        Iris-setosa
# 82        Iris-setosa
# 83        Iris-setosa
# 84        Iris-setosa
# 85        Iris-setosa
# 86        Iris-setosa
# 87        Iris-setosa
# 88        Iris-setosa
# 89        Iris-setosa
# 90        Iris-setosa
# 91        Iris-setosa
# 92        Iris-setosa
# 93        Iris-setosa
# 94        Iris-setosa
# 95        Iris-setosa
# 96        Iris-setosa
# 97        Iris-setosa
# 98        Iris-setosa
# 99        Iris-setosa
# 100       Iris-setosa
# 101       Iris-setosa
# 102       Iris-setosa
# 103       Iris-setosa
# 104       Iris-setosa
# Name: class, Length: 105, dtype: object

# %%
csvData.groupby('class').count()
# Out:
#                  petal_length  petal_width  sepal_length  sepal_width
# class
# Iris-setosa                35           35            35           35
# Iris-versicolor            35           35            35           35
# Iris-virginica             35           35            35           35

# %%
csvData.iloc[32:35,:]
# Out:
#              class  petal_length  petal_width  sepal_length  sepal_width
# 32  Iris-virginica           4.8          1.8           6.2          2.8
# 33  Iris-virginica           4.5          1.7           4.9          2.5
# 34  Iris-virginica           5.1          2.0           6.5          3.2

# %%
csvData.iloc[67:69,:]
# Out:
#               class  petal_length  petal_width  sepal_length  sepal_width
# 67  Iris-versicolor           4.5          1.5           6.0          2.9
# 68  Iris-versicolor           5.1          1.6           6.0          2.7

# %%
tsvData = pd.read_csv('./labeledTrainData.tsv',sep="\t")

# %%
tsvData.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
x = tsvData.review

# %%
y = tsvData.sentiment

# %%
x
# Out:
# 0        With all this stuff going down at the moment w...
# 1        \The Classic War of the Worlds\" by Timothy Hi...
# 2        The film starts with a manager (Nicholas Bell)...
# 3        It must be assumed that those who praised this...
# 4        Superbly trashy and wondrously unpretentious 8...
# 5        I dont know why people think this is such a ba...
# 6        This movie could have been very good, but come...
# 7        I watched this video at a friend's house. I'm ...
# 8        A friend of mine bought this film for £1, and ...
# 9        <br /><br />This movie is full of references. ...
# 10       What happens when an army of wetbacks, towelhe...
# 11       Although I generally do not like remakes belie...
# 12       \Mr. Harvey Lights a Candle\" is anchored by a...
# 13       I had a feeling that after \Submerged\", this ...
# 14       note to George Litman, and others: the Mystery...
# 15       Stephen King adaptation (scripted by King hims...
# 16       `The Matrix' was an exciting summer blockbuste...
# 17       Ulli Lommel's 1980 film 'The Boogey Man' is no...
# 18       This movie is one among the very few Indian mo...
# 19       Most people, especially young people, may not ...
# 20       \Soylent Green\" is one of the best and most d...
# 21       Michael Stearns plays Mike, a sexually frustra...
# 22       This happy-go-luck 1939 military swashbuckler,...
# 23       I would love to have that two hours of my life...
# 24       The script for this movie was probably found i...
# 25       Looking for Quo Vadis at my local video store,...
# 26       Note to all mad scientists everywhere: if you'...
# 27       What the ........... is this ? This must, with...
# 28       Intrigued by the synopsis (every gay video the...
# 29       Would anyone really watch this RUBBISH if it d...
#                                ...
# 24970    Red Rock West (1993)<br /><br />Nicolas Cage g...
# 24971    what can i say?, ms Erika Eleniak is my favori...
# 24972    The spoiler warning is for those people who wa...
# 24973    What do you call a horror story without horror...
# 24974    Though not a horror film in the traditional se...
# 24975    This was what black society was like before th...
# 24976    They probably should have called this movie Th...
# 24977    Attractive Marjorie(Farrah Fawcett)lives in fe...
# 24978    Vaguely reminiscent of great 1940's westerns, ...
# 24979    I admit I had no idea what to expect before vi...
# 24980    To me, the final scene, in which Harris respon...
# 24981    This is by far the funniest short made by the ...
# 24982    To be a Buster Keaton fan is to have your hear...
# 24983    I was one of those \few Americans\" that grew ...
# 24984    Visually disjointed and full of itself, the di...
# 24985    this movie had more holes than a piece of swis...
# 24986    Last November, I had a chance to see this film...
# 24987    First off, I'd like to make a correction on an...
# 24988    While originally reluctant to jump on the band...
# 24989    I heard about this movie when watching VH1's \...
# 24990    I've never been huge on IMAX films. They're co...
# 24991    Steve McQueen has certainly a lot of loyal fan...
# 24992    Sometimes you wonder how some people get fundi...
# 24993    I am a student of film, and have been for seve...
# 24994    Unimaginably stupid, redundant and humiliating...
# 24995    It seems like more consideration has gone into...
# 24996    I don't believe they made this film. Completel...
# 24997    Guy is a loser. Can't get girls, needs to buil...
# 24998    This 30 minute documentary Buñuel made in the ...
# 24999    I saw this movie as a child and it broke my he...
# Name: review, Length: 25000, dtype: object

# %%
import cv2

# %%
img = cv2.imread('./colin.jpeg')

# %%
cv2.imshow()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
import MySQLdb

# %%
import sqlite3

# %%
import pymongo

# %%
pd.read_sql_query()

# %%
fruit = {'name':['apple','orange','papaya','pine apple']
        ,'price':[200,150,65,80]}

# %%
fruit
# Out:
# {'name': ['apple', 'orange', 'papaya', 'pine apple'],
#  'price': [200, 150, 65, 80]}

# %%
df = pd.DataFrame(fruit)

# %%
df
# Out:
#          name  price
# 0       apple    200
# 1      orange    150
# 2      papaya     65
# 3  pine apple     80

# %%
df.to_csv("SRM_CSV.tsv",sep="\t")

# %%
df.to_excel("SRM_excel.xlsx")

# %%
DF = pd.DataFrame()

# %%
DF[" States"] = ['TamilNadu','kerala','Andhra pradesh']

# %%
DF['Language'] = ["Tamil","malayalam","Telugu"]

# %%
DF
# Out:
#            States   Language
# 0       TamilNadu      Tamil
# 1          kerala  malayalam
# 2  Andhra pradesh     Telugu

# %% [markdown]
# ### Multivariant data analysis

# %% [markdown]
# https://bit.ly/2Jx7mb6

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
data = pd.read_csv("./housePrediction/train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max
# Id                730.5    1095.25    1460.0
# MSSubClass         50.0      70.00     190.0
# LotFrontage        69.0      80.00     313.0
# LotArea          9478.5   11601.50  215245.0
# OverallQual         6.0       7.00      10.0
# OverallCond         5.0       6.00       9.0
# YearBuilt        1973.0    2000.00    2010.0
# YearRemodAdd     1994.0    2004.00    2010.0
# MasVnrArea          0.0     166.00    1600.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtUnfSF         477.5     808.00    2336.0
# TotalBsmtSF       991.5    1298.25    6110.0
# 1stFlrSF         1087.0    1391.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1464.0    1776.75    5642.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       8.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      14.0
# Fireplaces          1.0       1.00       3.0
# GarageYrBlt      1980.0    2002.00    2010.0
# GarageCars          2.0       2.00       4.0
# GarageArea        480.0     576.00    1418.0
# WoodDeckSF          0.0     168.00     857.0
# OpenPorchSF        25.0      68.00     547.0
# EnclosedPorch       0.0       0.00     552.0
# 3SsnPorch           0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      163000.0  214000.00  755000.0

# %%
data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
data['SalePrice'].plot(kind="hist")

# %%
sns.distplot(data['SalePrice'], fit = norm)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
data['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %%
data['SalePrice'] = np.log1p(data['SalePrice'])

# %%
sns.distplot(data['SalePrice'], fit = norm)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
data['SalePrice'].skew()
# Out:
# 0.12134661989685333

# %%
data.hist(bins=50, figsize=(30,20));

# %%
data['GrLivArea'] = np.log1p(data['GrLivArea'])

# %%
var = 'GrLivArea'
livingSales = pd.concat([data['SalePrice'], data[var]], axis=1)

# %%
livingSales.head()
# Out:
#    SalePrice  GrLivArea
# 0  12.247699   7.444833
# 1  12.109016   7.141245
# 2  12.317171   7.488294
# 3  11.849405   7.448916
# 4  12.429220   7.695758

# %%
livingSales.plot.scatter(x=var, y='SalePrice')

# %%
var = 'YearBuilt'
yearSales = pd.concat([data['SalePrice'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
plt.xticks(rotation=90);

# %%
corrmat = data.corr(method='spearman')
f, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(corrmat, ax=ax, cmap="YlGnBu", linewidths=0.1)

# %%
corrmat = data.corr(method='spearman')
cg = sns.clustermap(corrmat, cmap="YlGnBu", linewidths=0.1);
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
cg

# %%
data.groupby('SalePrice').count()
# Out:
#            Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# SalePrice
# 10.460271   1           1         1            1        1       1      0
# 10.471978   1           1         1            1        1       1      0
# 10.542733   1           1         1            1        1       1      0
# 10.579005   1           1         1            1        1       1      0
# 10.596660   1           1         1            1        1       1      1
# 10.859018   1           1         1            1        1       1      0
# 10.868587   1           1         1            1        1       1      1
# 10.915107   2           2         2            2        2       2      0
# 10.933000   1           1         1            1        1       1      0
# 10.976799   1           1         1            1        1       1      1
# 11.002117   3           3         3            3        3       3      0
# 11.018646   1           1         1            0        1       1      0
# 11.041064   1           1         1            1        1       1      0
# 11.074436   1           1         1            1        1       1      1
# 11.104972   1           1         1            1        1       1      0
# 11.112463   2           2         2            2        2       2      1
# 11.133143   1           1         1            1        1       1      0
# 11.134604   1           1         1            1        1       1      0
# 11.191356   1           1         1            0        1       1      0
# 11.198228   1           1         1            1        1       1      1
# 11.225257   1           1         1            1        1       1      0
# 11.231901   1           1         1            1        1       1      0
# 11.238502   1           1         1            1        1       1      0
# 11.245059   1           1         1            1        1       1      0
# 11.264477   1           1         1            1        1       1      0
# 11.277216   3           3         3            3        3       3      0
# 11.283525   1           1         1            1        1       1      0
# 11.288544   2           2         2            2        2       2      0
# 11.289794   4           4         4            3        4       4      0
# 11.296025   1           1         1            1        1       1      0
# ...        ..         ...       ...          ...      ...     ...    ...
# 12.886644   1           1         1            1        1       1      0
# 12.887130   1           1         1            1        1       1      0
# 12.904210   1           1         1            1        1       1      0
# 12.906349   1           1         1            1        1       1      0
# 12.906694   1           1         1            1        1       1      0
# 12.923915   1           1         1            1        1       1      0
# 12.929994   1           1         1            1        1       1      0
# 12.936754   1           1         1            1        1       1      0
# 12.955130   1           1         1            1        1       1      0
# 12.959541   1           1         1            1        1       1      0
# 12.962197   1           1         1            1        1       1      0
# 12.971543   1           1         1            0        1       1      0
# 12.988043   1           1         1            1        1       1      0
# 12.991756   1           1         1            1        1       1      0
# 12.994532   1           1         1            1        1       1      0
# 13.008662   1           1         1            1        1       1      0
# 13.021329   1           1         1            1        1       1      0
# 13.049795   1           1         1            1        1       1      0
# 13.053015   1           1         1            0        1       1      0
# 13.071072   1           1         1            1        1       1      0
# 13.091906   1           1         1            1        1       1      0
# 13.126033   1           1         1            1        1       1      0
# 13.195616   1           1         1            1        1       1      0
# 13.226725   1           1         1            1        1       1      0
# 13.229570   1           1         1            1        1       1      0
# 13.275829   1           1         1            1        1       1      0
# 13.323929   1           1         1            1        1       1      0
# 13.345509   1           1         1            1        1       1      0
# 13.521141   1           1         1            1        1       1      0
# 13.534474   1           1         1            1        1       1      0
#
#            LotShape  LandContour  Utilities      ...        ScreenPorch  \
# SalePrice                                        ...
# 10.460271         1            1          1      ...                  1
# 10.471978         1            1          1      ...                  1
# 10.542733         1            1          1      ...                  1
# 10.579005         1            1          1      ...                  1
# 10.596660         1            1          1      ...                  1
# 10.859018         1            1          1      ...                  1
# 10.868587         1            1          1      ...                  1
# 10.915107         2            2          2      ...                  2
# 10.933000         1            1          1      ...                  1
# 10.976799         1            1          1      ...                  1
# 11.002117         3            3          3      ...                  3
# 11.018646         1            1          1      ...                  1
# 11.041064         1            1          1      ...                  1
# 11.074436         1            1          1      ...                  1
# 11.104972         1            1          1      ...                  1
# 11.112463         2            2          2      ...                  2
# 11.133143         1            1          1      ...                  1
# 11.134604         1            1          1      ...                  1
# 11.191356         1            1          1      ...                  1
# 11.198228         1            1          1      ...                  1
# 11.225257         1            1          1      ...                  1
# 11.231901         1            1          1      ...                  1
# 11.238502         1            1          1      ...                  1
# 11.245059         1            1          1      ...                  1
# 11.264477         1            1          1      ...                  1
# 11.277216         3            3          3      ...                  3
# 11.283525         1            1          1      ...                  1
# 11.288544         2            2          2      ...                  2
# 11.289794         4            4          4      ...                  4
# 11.296025         1            1          1      ...                  1
# ...             ...          ...        ...      ...                ...
# 12.886644         1            1          1      ...                  1
# 12.887130         1            1          1      ...                  1
# 12.904210         1            1          1      ...                  1
# 12.906349         1            1          1      ...                  1
# 12.906694         1            1          1      ...                  1
# 12.923915         1            1          1      ...                  1
# 12.929994         1            1          1      ...                  1
# 12.936754         1            1          1      ...                  1
# 12.955130         1            1          1      ...                  1
# 12.959541         1            1          1      ...                  1
# 12.962197         1            1          1      ...                  1
# 12.971543         1            1          1      ...                  1
# 12.988043         1            1          1      ...                  1
# 12.991756         1            1          1      ...                  1
# 12.994532         1            1          1      ...                  1
# 13.008662         1            1          1      ...                  1
# 13.021329         1            1          1      ...                  1
# 13.049795         1            1          1      ...                  1
# 13.053015         1            1          1      ...                  1
# 13.071072         1            1          1      ...                  1
# 13.091906         1            1          1      ...                  1
# 13.126033         1            1          1      ...                  1
# 13.195616         1            1          1      ...                  1
# 13.226725         1            1          1      ...                  1
# 13.229570         1            1          1      ...                  1
# 13.275829         1            1          1      ...                  1
# 13.323929         1            1          1      ...                  1
# 13.345509         1            1          1      ...                  1
# 13.521141         1            1          1      ...                  1
# 13.534474         1            1          1      ...                  1
#
#            PoolArea  PoolQC  Fence  MiscFeature  MiscVal  MoSold  YrSold  \
# SalePrice
# 10.460271         1       0      1            0        1       1       1
# 10.471978         1       0      0            0        1       1       1
# 10.542733         1       0      1            0        1       1       1
# 10.579005         1       0      0            0        1       1       1
# 10.596660         1       0      1            0        1       1       1
# 10.859018         1       0      0            0        1       1       1
# 10.868587         1       0      0            0        1       1       1
# 10.915107         2       0      1            1        2       2       2
# 10.933000         1       0      0            1        1       1       1
# 10.976799         1       0      0            0        1       1       1
# 11.002117         3       0      0            0        3       3       3
# 11.018646         1       0      0            0        1       1       1
# 11.041064         1       0      1            0        1       1       1
# 11.074436         1       0      0            0        1       1       1
# 11.104972         1       0      0            0        1       1       1
# 11.112463         2       0      0            0        2       2       2
# 11.133143         1       0      0            0        1       1       1
# 11.134604         1       0      0            0        1       1       1
# 11.191356         1       0      0            0        1       1       1
# 11.198228         1       0      0            0        1       1       1
# 11.225257         1       0      0            0        1       1       1
# 11.231901         1       0      0            0        1       1       1
# 11.238502         1       0      0            0        1       1       1
# 11.245059         1       0      1            1        1       1       1
# 11.264477         1       0      1            0        1       1       1
# 11.277216         3       0      0            0        3       3       3
# 11.283525         1       0      0            1        1       1       1
# 11.288544         2       0      1            0        2       2       2
# 11.289794         4       0      1            0        4       4       4
# 11.296025         1       0      0            0        1       1       1
# ...             ...     ...    ...          ...      ...     ...     ...
# 12.886644         1       0      0            0        1       1       1
# 12.887130         1       0      0            0        1       1       1
# 12.904210         1       0      0            0        1       1       1
# 12.906349         1       0      0            0        1       1       1
# 12.906694         1       0      0            0        1       1       1
# 12.923915         1       0      0            0        1       1       1
# 12.929994         1       0      0            0        1       1       1
# 12.936754         1       0      0            0        1       1       1
# 12.955130         1       0      0            0        1       1       1
# 12.959541         1       0      0            0        1       1       1
# 12.962197         1       0      0            0        1       1       1
# 12.971543         1       0      0            0        1       1       1
# 12.988043         1       0      0            0        1       1       1
# 12.991756         1       0      0            0        1       1       1
# 12.994532         1       0      0            0        1       1       1
# 13.008662         1       0      0            0        1       1       1
# 13.021329         1       0      0            0        1       1       1
# 13.049795         1       0      0            0        1       1       1
# 13.053015         1       0      0            0        1       1       1
# 13.071072         1       0      1            0        1       1       1
# 13.091906         1       0      0            0        1       1       1
# 13.126033         1       0      0            0        1       1       1
# 13.195616         1       0      0            0        1       1       1
# 13.226725         1       0      0            0        1       1       1
# 13.229570         1       0      0            0        1       1       1
# 13.275829         1       0      0            0        1       1       1
# 13.323929         1       0      0            0        1       1       1
# 13.345509         1       0      0            0        1       1       1
# 13.521141         1       1      1            0        1       1       1
# 13.534474         1       0      0            0        1       1       1
#
#            SaleType  SaleCondition
# SalePrice
# 10.460271         1              1
# 10.471978         1              1
# 10.542733         1              1
# 10.579005         1              1
# 10.596660         1              1
# 10.859018         1              1
# 10.868587         1              1
# 10.915107         2              2
# 10.933000         1              1
# 10.976799         1              1
# 11.002117         3              3
# 11.018646         1              1
# 11.041064         1              1
# 11.074436         1              1
# 11.104972         1              1
# 11.112463         2              2
# 11.133143         1              1
# 11.134604         1              1
# 11.191356         1              1
# 11.198228         1              1
# 11.225257         1              1
# 11.231901         1              1
# 11.238502         1              1
# 11.245059         1              1
# 11.264477         1              1
# 11.277216         3              3
# 11.283525         1              1
# 11.288544         2              2
# 11.289794         4              4
# 11.296025         1              1
# ...             ...            ...
# 12.886644         1              1
# 12.887130         1              1
# 12.904210         1              1
# 12.906349         1              1
# 12.906694         1              1
# 12.923915         1              1
# 12.929994         1              1
# 12.936754         1              1
# 12.955130         1              1
# 12.959541         1              1
# 12.962197         1              1
# 12.971543         1              1
# 12.988043         1              1
# 12.991756         1              1
# 12.994532         1              1
# 13.008662         1              1
# 13.021329         1              1
# 13.049795         1              1
# 13.053015         1              1
# 13.071072         1              1
# 13.091906         1              1
# 13.126033         1              1
# 13.195616         1              1
# 13.226725         1              1
# 13.229570         1              1
# 13.275829         1              1
# 13.323929         1              1
# 13.345509         1              1
# 13.521141         1              1
# 13.534474         1              1
#
# [663 rows x 80 columns]

# %% [markdown]
# ### Time series

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv("AirPassengers.csv")

# %%
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m')

data = pd.read_csv('AirPassengers.csv', parse_dates=['Month'], index_col='Month',date_parser=dateparse)

# %%
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
ts = data['#Passengers']

# %%
ts
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# 1950-01-01    115
# 1950-02-01    126
# 1950-03-01    141
# 1950-04-01    135
# 1950-05-01    125
# 1950-06-01    149
# 1950-07-01    170
# 1950-08-01    170
# 1950-09-01    158
# 1950-10-01    133
# 1950-11-01    114
# 1950-12-01    140
# 1951-01-01    145
# 1951-02-01    150
# 1951-03-01    178
# 1951-04-01    163
# 1951-05-01    172
# 1951-06-01    178
#              ...
# 1958-07-01    491
# 1958-08-01    505
# 1958-09-01    404
# 1958-10-01    359
# 1958-11-01    310
# 1958-12-01    337
# 1959-01-01    360
# 1959-02-01    342
# 1959-03-01    406
# 1959-04-01    396
# 1959-05-01    420
# 1959-06-01    472
# 1959-07-01    548
# 1959-08-01    559
# 1959-09-01    463
# 1959-10-01    407
# 1959-11-01    362
# 1959-12-01    405
# 1960-01-01    417
# 1960-02-01    391
# 1960-03-01    419
# 1960-04-01    461
# 1960-05-01    472
# 1960-06-01    535
# 1960-07-01    622
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
ts['1960-10-01']
# Out:
# 461

# %%
ts['1960']
# Out:
# Month
# 1960-01-01    417
# 1960-02-01    391
# 1960-03-01    419
# 1960-04-01    461
# 1960-05-01    472
# 1960-06-01    535
# 1960-07-01    622
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: #Passengers, dtype: int64

# %%
plt.plot(ts)

# %%
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

test_stationarity(ts)

# %%
ts_log = np.log(ts)

ts_log_diff = ts_log - ts_log.shift()

# %%
ts_log_diff
# Out:
# Month
# 1949-01-01         NaN
# 1949-02-01    0.052186
# 1949-03-01    0.112117
# 1949-04-01   -0.022990
# 1949-05-01   -0.064022
# 1949-06-01    0.109484
# 1949-07-01    0.091937
# 1949-08-01    0.000000
# 1949-09-01   -0.084557
# 1949-10-01   -0.133531
# 1949-11-01   -0.134733
# 1949-12-01    0.126294
# 1950-01-01   -0.025752
# 1950-02-01    0.091350
# 1950-03-01    0.112478
# 1950-04-01   -0.043485
# 1950-05-01   -0.076961
# 1950-06-01    0.175633
# 1950-07-01    0.131852
# 1950-08-01    0.000000
# 1950-09-01   -0.073203
# 1950-10-01   -0.172246
# 1950-11-01   -0.154151
# 1950-12-01    0.205444
# 1951-01-01    0.035091
# 1951-02-01    0.033902
# 1951-03-01    0.171148
# 1951-04-01   -0.088033
# 1951-05-01    0.053744
# 1951-06-01    0.034289
#                 ...
# 1958-07-01    0.121098
# 1958-08-01    0.028114
# 1958-09-01   -0.223144
# 1958-10-01   -0.118092
# 1958-11-01   -0.146750
# 1958-12-01    0.083511
# 1959-01-01    0.066021
# 1959-02-01   -0.051293
# 1959-03-01    0.171542
# 1959-04-01   -0.024939
# 1959-05-01    0.058841
# 1959-06-01    0.116724
# 1959-07-01    0.149296
# 1959-08-01    0.019874
# 1959-09-01   -0.188422
# 1959-10-01   -0.128914
# 1959-11-01   -0.117169
# 1959-12-01    0.112243
# 1960-01-01    0.029199
# 1960-02-01   -0.064379
# 1960-03-01    0.069163
# 1960-04-01    0.095527
# 1960-05-01    0.023581
# 1960-06-01    0.125288
# 1960-07-01    0.150673
# 1960-08-01   -0.026060
# 1960-09-01   -0.176399
# 1960-10-01   -0.097083
# 1960-11-01   -0.167251
# 1960-12-01    0.102279
# Name: #Passengers, Length: 144, dtype: float64

# %%
ts_log_diff.dropna(inplace=True)

# %%
test_stationarity(ts_log_diff)
plt.plot(ts_log_diff)

# %%
from statsmodels.tsa.arima_model import ARIMA
from random import random

# %%
# contrived dataset
data = [x + random() for x in range(1, 100)]

# %%
data
# Out:
# [1.9072262815804528,
#  2.8058647722629555,
#  3.377533861949623,
#  4.594493222818641,
#  5.937428832411156,
#  6.0283902572809485,
#  7.021876736141522,
#  8.945220180420156,
#  9.182241018213922,
#  10.733933994303525,
#  11.213628923471862,
#  12.052906821063871,
#  13.074247277714878,
#  14.601317124434326,
#  15.947726397126303,
#  16.014188226006393,
#  17.13583849015985,
#  18.775498566221007,
#  19.55415295283648,
#  20.022376297122154,
#  21.477919641730228,
#  22.35580890997771,
#  23.954054077058014,
#  24.758351812115936,
#  25.824438041747854,
#  26.364437026874988,
#  27.08658362527401,
#  28.492825467581884,
#  29.037499721328846,
#  30.42907903399247,
#  31.650430692245806,
#  32.00135734303137,
#  33.682743095103206,
#  34.77338671816483,
#  35.71525969255152,
#  36.28769274104935,
#  37.386250101490674,
#  38.037136868138106,
#  39.24766316090553,
#  40.67696220119447,
#  41.19349641417089,
#  42.97348306702745,
#  43.80540381324584,
#  44.70702403726046,
#  45.99668384682198,
#  46.11866153400896,
#  47.151304922492145,
#  48.19783776749793,
#  49.78384716263551,
#  50.38037229518415,
#  51.35904975946714,
#  52.07801394186566,
#  53.805227781229014,
#  54.04589924236167,
#  55.44292258498269,
#  56.54460828235982,
#  57.52103793342082,
#  58.108307313445955,
#  59.79099185861359,
#  60.52736231155183,
#  61.08265551689985,
#  62.30765596428255,
#  63.42643585306017,
#  64.39407924770364,
#  65.69958306591286,
#  66.42001135698406,
#  67.74905745551025,
#  68.90600627193388,
#  69.9273753506169,
#  70.38444166052574,
#  71.48045866284188,
#  72.43483909810814,
#  73.92116689940846,
#  74.6412889969327,
#  75.03402391091471,
#  76.4108368243153,
#  77.56796463414514,
#  78.28030974377677,
#  79.80190562304506,
#  80.97165739462379,
#  81.15778557274378,
#  82.66344135325242,
#  83.94257558636306,
#  84.76626430082358,
#  85.69740409856166,
#  86.27791820193455,
#  87.32524823349272,
#  88.79950252277392,
#  89.7907522806852,
#  90.68061471924167,
#  91.68480999823284,
#  92.1416729084394,
#  93.43114856019245,
#  94.41640999708716,
#  95.03446601745232,
#  96.20304659278173,
#  97.13892311334662,
#  98.80199394185529,
#  99.39257274641741]

# %%
# fit model
model = ARIMA(data, order=(1, 1, 1))
model_fit = model.fit(disp=False)

# %%
model_fit.params
# Out:
# array([ 1.00050514,  0.04565637, -0.99996886])

# %%
# make prediction
yhat = model_fit.predict(len(data), len(data), typ='levels')
print(yhat)
# Out:
# [100.50513045]

# %%
model.predict(['1962-09-01'])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)

# %%
frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Eggs, Kidney Beans)
# 6       0.6                (Eggs, Onion)
# 7       0.6         (Milk, Kidney Beans)
# 8       0.6        (Kidney Beans, Onion)
# 9       0.6       (Kidney Beans, Yogurt)
# 10      0.6  (Eggs, Kidney Beans, Onion)
