# %%
print("hello world")
# Out:
# hello world

# %%
a = 5
b = 10
print(a+b)
# Out:
# 15

# %%
a = 5#int
f = 3.14#float
s = 'apple'#string
b = True#bool

# %%
print(type(s))
print(type(b))
# Out:
# <class 'str'>
# <class 'bool'>

# %%
print(f)
# Out:
# 3.14

# %%
print(4)
# Out:
# 4
