# %%
print("hello world")
# Out:
# hello world

# %%
a=5
b=3.14
c='apple'
d=True

# %%
student_name=""
studentName=

# %%
print(1223445)
# Out:
# 1223445

# %%
print("mango")
# Out:
# mango

# %%
print(a)
# Out:
# 5

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
g = 10
print(a+g)
# Out:
# 15

# %%
num =  input("Enter any numerical value :")
num = int(num)
if num % 2 == 0:
    print('even')
else:
    print('odd')
# Out:
# Enter any numerical value :14
# even

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
num =  int(input("Enter any numerical value :"))
if num % 2 == 0:
    print('even')
else:
    print('odd')
# Out:
# Enter any numerical value :j
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f422d83b9561> in <module>
# ----> 1 num =  int(input("Enter any numerical value :"))
#       2 if num % 2 == 0:
#       3     print('even')
#       4 else:
#       5     print('odd')
#
# ValueError: invalid literal for int() with base 10: 'j'

# %%
i = 1
while i <= 3:
    num =  int(input("Enter any numerical value :"))
    if num % 4 == 0:
        print("divisible by 4 and even")
    elif num % 2 == 0:
        print('even')
    else:
        print('odd')
        
    i = i + 1 # i += 1
else:
    print("iterations are over")
# Out:
# Enter any numerical value :24
# divisible by 4 and even
# Enter any numerical value :356
# divisible by 4 and even
# Enter any numerical value :56
# divisible by 4 and even
# iterations are over

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10,21,2):
    print(i)
# Out:
# 10
# 12
# 14
# 16
# 18
# 20

# %%
for i in range(len(c)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    num =  int(input("Enter any numerical value :"))
    
    if num == 25:
        print("stopping")
        break
        
    if num % 4 == 0:
        print("divisible by 4 and even")
    elif num % 2 == 0:
        print('even')
    else:
        print('odd')
# Out:
# Enter any numerical value :12
# divisible by 4 and even
# Enter any numerical value :45
# odd
# Enter any numerical value :25
# stopping

# %%
def addition(): # no arg no return
    a = int(input("A :"))
    b = int(input("B :"))
    print(a+b,a*b)

# %%
addition()
# Out:
# A :5
# B :4
# 9 20

# %%
def addition(): # no arg with return
    a = int(input("A :"))
    b = int(input("B :"))
    return a+b,a*b

# %%
s,m = addition()
# Out:
# A :8
# B :4

# %%
print(s,m)
# Out:
# 12 32

# %%
def addition(a,b): # arg with return
    return a+b,a*b

# %%
def addition(b,a=10): # arg with return with default value
    return a+b,a*b

# %%
c = int(input("A :"))
d = int(input("B :"))
ans = addition(c,d)
# Out:
# A :4
# B :7

# %%
print(ans)
# Out:
# (11, 28)

# %%
print(ans[0])
print(ans[1])
# Out:
# 11
# 28

# %%
print(addition(5))
# Out:
# (15, 50)

# %%
print(addition(5,3))
# Out:
# (8, 15)

# %%
pip install libraryName

pip install opencv-python

# %%
import math

# %%
print(math.factorial(5))
# Out:
# 120

# %%
import math as m

# %%
print(m.factorial(6), m.sqrt(16))
# Out:
# 720 4.0

# %%
from random import randint, choice

# %%
print(randint(0,10))
# Out:
# 1

# %%
from random import *

# %%
sample(),randrange()

# %%
import cv2

# %%
image = cv2.imread("../vision_example/girls.jpg")

# %%
blurred = cv2.blur(image,(1,2))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(blurred)

# %%
cv2.blur?
