# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("./weather.csv")

# %%
ohe = LabelEncoder()

# %%
ohe.fit_transform(["sunny","sunny","overc"])
# Out:
# array([2, 2, 1, 0, 0, 0, 1, 2, 2, 0, 2, 1, 1, 0])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
np.random.seed(12)

races =   ["asian","black","hispanic","other","white"]

# Generate random data
voter_race = np.random.choice(a= races,
                              p = [0.05, 0.15 ,0.25, 0.05, 0.5],
                              size=1000)

voter_age = stats.poisson.rvs(loc=18,
                              mu=30,
                              size=1000)

# Group age data by race
voter_frame = pd.DataFrame({"race":voter_race,"age":voter_age})

# %%
groups = voter_frame.groupby("race").groups

# Etract individual groups
asian = voter_age[groups["asian"]]
black = voter_age[groups["black"]]
hispanic = voter_age[groups["hispanic"]]
other = voter_age[groups["other"]]
white = voter_age[groups["white"]]

# Perform the ANOVA
stats.f_oneway(asian, black, hispanic, other, white)
# Out:
# F_onewayResult(statistic=1.7744689357329695, pvalue=0.13173183201930463)

# %%
np.random.choice?

# %%
stats.poisson.rvs?

# %%
asian
# Out:
# array([56, 52, 37, 50, 53, 47, 56, 43, 46, 54, 45, 54, 42, 44, 55, 50, 45,
#        49, 51, 57, 56, 46, 43, 53, 48, 54, 54, 44, 40, 46, 51, 52, 44, 54,
#        43, 44, 53, 42, 54, 44, 59, 47, 54, 40])

# %%
np.random.seed(12)

# Generate random data
voter_race = np.random.choice(a= races,
                              p = [0.05, 0.15 ,0.25, 0.05, 0.5],
                              size=1000)

# Use a different distribution for white ages
white_ages = stats.poisson.rvs(loc=18, 
                              mu=32,
                              size=1000)

voter_age = stats.poisson.rvs(loc=18,
                              mu=30,
                              size=1000)

voter_age = np.where(voter_race=="white", white_ages, voter_age)

# Group age data by race
voter_frame = pd.DataFrame({"race":voter_race,"age":voter_age})
groups = voter_frame.groupby("race").groups   

# Extract individual groups
asian = voter_age[groups["asian"]]
black = voter_age[groups["black"]]
hispanic = voter_age[groups["hispanic"]]
other = voter_age[groups["other"]]
white = voter_age[groups["white"]]

# Perform the ANOVA
stats.f_oneway(asian, black, hispanic, other, white)
# Out:
# F_onewayResult(statistic=10.164699828386366, pvalue=4.5613242113994585e-08)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=voter_age,     # Data
                          groups=voter_race,   # Groups
                          alpha=0.05)          # Significance level

tukey.plot_simultaneous()    # Plot group confidence intervals
plt.vlines(x=49.57,ymin=-0.5,ymax=4.5, color="red")

tukey.summary()              # See test summary
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
import cv2

# %%
ima = cv2.imread('../Downloads/besoinsNew.jpeg')

# %%
cv2.imshow('ma',ima)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
re = cv2.resize(ima,(200,164))

# %%
cv2.imshow('ma',re)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ima.shape
# Out:
# (164, 514, 3)

# %%
re.shape
# Out:
# (164, 200, 3)

# %%
cv2.imwrite('../Downloads/besoinsNewEdited.jpeg', re)
# Out:
# True

# %%
dataset = pd.read_csv('/home/sharma/november_2020/durga/train1.csv')

# %%
dataset.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  40.696524  -73.991617
# ...

# %%
dataset['price'] = np.exp(dataset['log_price'])

# %%
dataset.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   longitude  \
# 0  Real Bed              strict          True  ...  -73.991617
# ...

# %%
# displaying top-5 rows and properties of the dataset
print("Top-5 rows of the dataset")
display(dataset.head())

row, col = dataset.shape
print(f"\nThe number of rows and columns in the dataset: {row} and {col}")

print('\nDescriptive analysis of the dataset')
display(dataset.describe())

print(f'\nColumns in the datasets are : {list(dataset.columns)}')

# preprocessing datasets
# checking for the missing values
preprocessDataframe = dataset.isnull().sum(axis=0).reset_index()
preprocessDataframe.columns = ['column', 'count']
preprocessDataframe = preprocessDataframe.loc[preprocessDataframe['count'] > 0].sort_values(by='count')
print('\nDisplaying columns with number of count')
display(preprocessDataframe)

# adding column price
dataset['price'] = np.exp(dataset['log_price'])

# dropping unwanted columns
col = ['log_price','id', 'neighbourhood', 'name','description','thumbnail_url','amenities', 'first_review',
       'last_review', 'host_since', 'host_has_profile_pic', 'latitude','longitude']
dataset.drop(col, axis = 1, inplace=True)

# filling dataframe
dataset.update(dataset[['bathrooms','bedrooms','beds', 'review_scores_rating', 'zipcode', 'host_identity_verified',
                        'host_response_rate']].fillna(0))
dataset['host_response_rate'] = dataset.host_response_rate.apply(lambda x: int(str(x).strip('%')))
dataset['host_identity_verified'] = np.where(dataset.host_identity_verified == 't',1 ,0)
# Out:
# Top-5 rows of the dataset
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   longitude  \
# 0  Real Bed              strict          True  ...  -73.991617
# ...

# %%
col = ['log_price','id', 'neighbourhood', 'name','description','thumbnail_url','amenities', 'first_review', 'last_review', 'host_since', 'host_has_profile_pic', 'latitude','longitude']

dataset.drop(col, axis = 1, inplace=True)

# %%
dataset.head()
# Out:
#   property_type        room_type  accommodates  bathrooms  bed_type  \
# 0     Apartment  Entire home/apt             3        1.0  Real Bed
# 1     Apartment  Entire home/apt             7        1.0  Real Bed
# 2     Apartment  Entire home/apt             5        1.0  Real Bed
# 3         House  Entire home/apt             4        1.0  Real Bed
# 4     Apartment  Entire home/apt             2        1.0  Real Bed
#
#   cancellation_policy  cleaning_fee city  host_identity_verified  \
# 0              strict          True  NYC                       1
# 1              strict          True  NYC                       0
# 2            moderate          True  NYC                       1
# 3            flexible          True   SF                       1
# 4            moderate          True   DC                       1
#
#    host_response_rate instant_bookable  number_of_reviews  \
# 0                   0                f                  2
# ...

# %%
dataset.shape
# Out:
# (74111, 17)

# %%
dataset['bathrooms'] = dataset['bathrooms'].fillna(0)
dataset['bedrooms'] = dataset['bedrooms'].fillna(0)
dataset['beds'] = dataset['beds'].fillna(0)
dataset['review_scores_rating'] = dataset['review_scores_rating'].fillna(0)
dataset['zipcode'] = dataset['zipcode'].fillna(0)
dataset['host_identity_verified'] = dataset['host_identity_verified'].fillna(0)

# %%
dataset.update(dataset[['bathrooms','bedrooms','beds', 'review_scores_rating', 'zipcode', 'host_identity_verified','host_response_rate']].fillna(0))

# %%
dataset.head()
# Out:
#   property_type        room_type  accommodates  bathrooms  bed_type  \
# 0     Apartment  Entire home/apt             3        1.0  Real Bed
# 1     Apartment  Entire home/apt             7        1.0  Real Bed
# 2     Apartment  Entire home/apt             5        1.0  Real Bed
# 3         House  Entire home/apt             4        1.0  Real Bed
# 4     Apartment  Entire home/apt             2        1.0  Real Bed
#
#   cancellation_policy  cleaning_fee city  host_identity_verified  \
# 0              strict          True  NYC                       1
# 1              strict          True  NYC                       0
# 2            moderate          True  NYC                       1
# 3            flexible          True   SF                       1
# 4            moderate          True   DC                       1
#
#    host_response_rate instant_bookable  number_of_reviews  \
# 0                   0                f                  2
# ...

# %%
dataset.isna().any()
# Out:
# property_type             False
# room_type                 False
# accommodates              False
# bathrooms                 False
# bed_type                  False
# cancellation_policy       False
# cleaning_fee              False
# city                      False
# host_identity_verified    False
# host_response_rate        False
# instant_bookable          False
# number_of_reviews         False
# review_scores_rating      False
# zipcode                   False
# bedrooms                  False
# beds                      False
# price                     False
# dtype: bool

# %%
pd.to_numeric(dataset.host_response_rate.apply(lambda x: str(x).strip('%')))
# Out:
# 0          0
# 1        100
# 2        100
# 3          0
# 4        100
#         ...
# 74106      0
# 74107    100
# 74108    100
# 74109    100
# 74110    100
# Name: host_response_rate, Length: 74111, dtype: int64

# %%
dataset.host_identity_verified
# Out:
# 0        t
# 1        f
# 2        t
# 3        t
# 4        t
#         ..
# 74106    t
# 74107    f
# 74108    t
# 74109    f
# 74110    t
# Name: host_identity_verified, Length: 74111, dtype: object

# %%
import numpy as np

# %%
np.where(dataset.host_identity_verified == 't',1 ,0)
# Out:
# array([1, 0, 1, ..., 1, 0, 1])

# %%
dataset.property_type
# Out:
# 0        Apartment
# 1        Apartment
# 2        Apartment
# 3            House
# 4        Apartment
#            ...
# 74106    Apartment
# 74107    Apartment
# 74108    Apartment
# 74109    Apartment
# 74110         Boat
# Name: property_type, Length: 74111, dtype: object

# %%
dataset.groupby('property_type').count().sort_values('bed_type')
# Out:
#                     room_type  accommodates  bathrooms  bed_type  \
# property_type
# Parking Space               1             1          1         1
# Lighthouse                  1             1          1         1
# Island                      1             1          1         1
# Casa particular             1             1          1         1
# Train                       2             2          2         2
# Cave                        2             2          2         2
# Tipi                        3             3          3         3
# Earth House                 4             4          4         4
# Chalet                      6             6          6         6
# Treehouse                   7             7          7         7
# Hut                         8             8          8         8
# Yurt                        9             9          9         9
# Vacation home              11            11         11        11
# ...

# %%
dataset
# Out:
#       property_type        room_type  accommodates  bathrooms  bed_type  \
# 0         Apartment  Entire home/apt             3        1.0  Real Bed
# 1         Apartment  Entire home/apt             7        1.0  Real Bed
# 2         Apartment  Entire home/apt             5        1.0  Real Bed
# 3             House  Entire home/apt             4        1.0  Real Bed
# 4         Apartment  Entire home/apt             2        1.0  Real Bed
# ...             ...              ...           ...        ...       ...
# 74106     Apartment     Private room             1        1.0  Real Bed
# 74107     Apartment  Entire home/apt             4        2.0  Real Bed
# 74108     Apartment  Entire home/apt             5        1.0  Real Bed
# 74109     Apartment  Entire home/apt             2        1.0  Real Bed
# 74110          Boat  Entire home/apt             4        1.0  Real Bed
#
#       cancellation_policy  cleaning_fee city host_identity_verified  \
# ...

# %%
from sklearn.preprocessing import LabelBinarizer, LabelEncoder

# %%
def encodeDatasets(df, columns):
    for i, column in enumerate(columns):
        lb = LabelEncoder()
        df[column] = lb.fit_transform(df[column])
    return df

# %%
dataset
# Out:
#        property_type  room_type  accommodates  bathrooms  bed_type  \
# 0                  0          0             3        1.0         4
# 1                  0          0             7        1.0         4
# 2                  0          0             5        1.0         4
# 3                 17          0             4        1.0         4
# 4                  0          0             2        1.0         4
# ...              ...        ...           ...        ...       ...
# 74106              0          1             1        1.0         4
# 74107              0          0             4        2.0         4
# 74108              0          0             5        1.0         4
# 74109              0          0             2        1.0         4
# 74110              2          0             4        1.0         4
#
#        cancellation_policy  cleaning_fee  city  host_identity_verified  \
# 0                        2          True     4                       1
# ...

# %%
encodeDatasets(dataset,['city','property_type', 'room_type', 'bed_type', 'cancellation_policy', 'host_response_rate'])
# Out:
#        property_type  room_type  accommodates  bathrooms  bed_type  \
# 0                  0          0             3        1.0         4
# 1                  0          0             7        1.0         4
# 2                  0          0             5        1.0         4
# 3                 17          0             4        1.0         4
# 4                  0          0             2        1.0         4
# ...              ...        ...           ...        ...       ...
# 74106              0          1             1        1.0         4
# 74107              0          0             4        2.0         4
# 74108              0          0             5        1.0         4
# 74109              0          0             2        1.0         4
# 74110              2          0             4        1.0         4
#
#        cancellation_policy  cleaning_fee  city  host_identity_verified  \
# 0                        2          True     4                       1
# ...

# %%
set(dataset['host_identity_verified'])
# Out:
# {0, 1}

# %%
X = dataset.loc[:, :'beds']
x = np.asarray(X).astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-56c59c850118> in <module>
#       1 X = dataset.loc[:, :'beds']
# ----> 2 x = np.asarray(X).astype(np.float32)
#
# ValueError: could not convert string to float:

# %%
dataset.drop(columns='instant_bookable', inplace=True)

# %%
np.asarray(X.iloc[:,:12]).astype(np.float32)
# Out:
# array([[  0.,   0.,   3., ...,   0.,   2., 100.],
#        [  0.,   0.,   7., ...,  79.,   6.,  93.],
#        [  0.,   0.,   5., ...,  79.,  10.,  92.],
#        ...,
#        [  0.,   0.,   5., ...,  79.,  43.,  94.],
#        [  0.,   0.,   2., ...,  79.,   0.,   0.],
#        [  2.,   0.,   4., ...,  79., 205.,  96.]], dtype=float32)

# %%
X.columns
# Out:
# Index(['property_type', 'room_type', 'accommodates', 'bathrooms', 'bed_type',
#        'cancellation_policy', 'cleaning_fee', 'city', 'host_identity_verified',
#        'host_response_rate', 'number_of_reviews', 'review_scores_rating',
#        'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
np.asarray(X.zipcode).astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-302246249884> in <module>
# ----> 1 np.asarray(X.zipcode).astype(np.float32)
#
# ValueError: could not convert string to float:

# %%
set(X.zipcode)
# Out:
# {' ',
#  0,
#  '02108',
#  '02109',
#  '02110',
#  '02111',
#  '02113',
#  '02114',
#  '02115',
#  '02116',
#  '02118',
#  '02119',
#  '02120',
#  '02121',
#  '02122',
#  '02124',
#  '02125',
#  '02126',
#  '02127',
#  '02128',
#  '02129',
#  '02130',
#  '02131',
#  '02132',
#  '02134',
#  '02135',
#  '02136',
#  '02138',
#  '02139',
#  '02143',
#  '02145',
#  '02152',
#  '02163',
#  '02186',
#  '02199',
#  '02210',
#  '02215',
#  '02445',
#  '02446',
#  '02458',
#  '02467',
#  '02472',
#  '07306',
#  '10000',
#  '10001',
#  '10001.0',
#  '10002',
#  '10002-2289',
#  '10002.0',
#  '10003',
#  '10003-8623',
#  '10003.0',
#  '10004',
#  '10004.0',
#  '10005',
#  '10006',
#  '10007',
#  '10007.0',
#  '10009',
#  '10009.0',
#  '10010',
#  '10010.0',
#  '10011',
#  '10011.0',
#  '10012',
#  '10012.0',
#  '10013',
#  '10013.0',
#  '10014',
#  '10014.0',
#  '10016',
#  '10016.0',
#  '10017',
#  '10018',
#  '10018.0',
#  '10019',
#  '10019.0',
#  '10021',
#  '10022',
#  '10023',
#  '10024',
# ...

# %%
X[X.zipcode == '95202\r\r\r\r\r\r\n\r\r\r\r\r\r\n\r\r\r\r\r\r\n94158']
# Out:
#       property_type  room_type  accommodates  bathrooms  bed_type  \
# 8264              0          1             1        1.0         4
#
#       cancellation_policy  cleaning_fee  city  host_identity_verified  \
# 8264                    0          True     5                       1
#
#       host_response_rate  number_of_reviews  review_scores_rating  \
# 8264                  79                  5                  95.0
#
#                                                 zipcode  bedrooms  beds
# 8264  95202\r\r\r\r\r\r\n\r\r\r\r\r\r\n\r\r\r\r\r\r\...       1.0   1.0

# %%
'95202\r\r\r\r\r\r\n\r\r\r\r\r\r\n\r\r\r\r\r\r\n94158'.replace('\r','').replace('\n','')
# Out:
# '9520294158'

# %%
import re
''.join(re.findall(r'\d+', '95202\r\r\r\r\r\r\n\r\r\r\r\r\r\n\r\r\r\r\r\r\n94158'))
# Out:
# '9520294158'

# %%
import numpy as np
import pytesseract
import cv2


image = cv2.imread('check.png')
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower = np.array([103,79,60])
upper = np.array([129,255,255])
mask = cv2.inRange(hsv, lower, upper)

cnts = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    area = cv2.contourArea(c)
    if area < 10:
        cv2.drawContours(mask, [c], -1, (0,0,0), -1)

mask = 255 - mask
mask = cv2.GaussianBlur(mask, (3,3), 0)

data = pytesseract.image_to_string(mask, lang='eng',config='--psm 6')
print(data)

cv2.imshow('mask', mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# O7/OV//201I8
# ACME Grocery Shop Bib
# EIGHT AND I6b /IOO -—~~~~YT ~~
# Lunch w/Friends (jane Doe

# %%
import numpy as np
import pytesseract
import cv2


image = cv2.imread('check.png')
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower = np.array([103,79,60])
upper = np.array([129,255,255])
mask = cv2.inRange(hsv, lower, upper)

cnts = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    area = cv2.contourArea(c)
    if area < 10:
        cv2.drawContours(mask, [c], -1, (0,0,0), -1)

mask = 255 - mask
mask = cv2.GaussianBlur(mask, (3,3), 0)

data = pytesseract.image_to_string(mask, lang='mcr')
print(data)

cv2.imshow('mask', mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 07$0@3080
#
# 80-6 0@000@-7$ 51907 0@0
# 68087 8-0 @5-00
#
#
#
# 40-06 --5-00025 8-8006

# %%
import numpy as np
import pytesseract
import cv2
import os
image = cv2.imread('check.png')

print(pytesseract.image_to_string(image, lang='mcr'))
# Out:
# 3202 002 700
#
# 320-8-50 02-0720-080
#
# 60--0@2 05 3030
#
# 8
# @52820878966 -60-945804 6 00
#
# 68 87 0 @5-00 00-@25
#
# 70- 8804
# 1150 -850 52
# 60-2@0 05 3003
#
# -6-0 400000 -275-00085 [-
#
# [123456789[ 1001001239@ 0790

# %%
# !wget https://github.com/BigPino67/Tesseract-MICR-OCR/blob/master/Tessdata/mcr.traineddata
# Out:
# --2020-12-26 08:08:47--  https://github.com/BigPino67/Tesseract-MICR-OCR/blob/master/Tessdata/mcr.traineddata
# Resolving github.com (github.com)... 13.234.210.38
# Connecting to github.com (github.com)|13.234.210.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘mcr.traineddata’
#
# mcr.traineddata         [ <=>                ]  86.38K  --.-KB/s    in 0.02s
#
# 2020-12-26 08:08:48 (5.18 MB/s) - ‘mcr.traineddata’ saved [88449]

# %%
# !cp mcr.traineddata /usr/share/tesseract-ocr/4.00/tessdata
# Out:
# cp: cannot create regular file '/usr/share/tesseract-ocr/4.00/tessdata/mcr.traineddata': Permission denied

# %%
https://github.com/tesseract-ocr/tessdata/blob/master/eng.traineddata?raw=true
# Out:
# --2020-12-26 09:07:12--  https://github.com/BigPino67/Tesseract-MICR-OCR/blob/master/Tessdata/mcr.traineddata?raw=true
# Resolving github.com (github.com)... 13.234.210.38
# Connecting to github.com (github.com)|13.234.210.38|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/BigPino67/Tesseract-MICR-OCR/raw/master/Tessdata/mcr.traineddata [following]
# --2020-12-26 09:07:12--  https://github.com/BigPino67/Tesseract-MICR-OCR/raw/master/Tessdata/mcr.traineddata
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/BigPino67/Tesseract-MICR-OCR/master/Tessdata/mcr.traineddata [following]
# --2020-12-26 09:07:13--  https://raw.githubusercontent.com/BigPino67/Tesseract-MICR-OCR/master/Tessdata/mcr.traineddata
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.56.133
# ...
